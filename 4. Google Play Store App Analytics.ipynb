# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                             App        Category  Rating  Reviews  Size_MBs  \
# 2281  Vargo Anesthesia Mega App         MEDICAL    4.60       92     32.00
# 1229        Cr Aviation Academy          FAMILY    5.00        7     22.00
# 6010                     Hemnet  HOUSE_AND_HOME    3.60     4087      9.20
# 3644                       Ring   COMMUNICATION    3.90      517     35.00
# 6097               CVS Caremark         MEDICAL    3.50     3707     10.00
#
#      Installs  Type   Price Content_Rating         Genres    Last_Updated  \
# 2281    1,000  Paid  $79.99       Everyone        Medical   June 18, 2018
# 1229      100  Free       0       Everyone      Education  August 9, 2017
# 6010  500,000  Free       0       Everyone   House & Home   July 16, 2018
# 3644   10,000  Free       0       Everyone  Communication  August 6, 2018
# 6097  500,000  Free       0       Everyone        Medical   July 28, 2018
#
#        Android_Ver
# 2281  4.0.3 and up
# 1229    4.1 and up
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/1f/1w554m957mz1kkr7yftsx8qr0000gn/T/ipykernel_59527/2576723297.py in <module>
# ----> 1 df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1, inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
# Check code above worked correctly.
df_apps.shape
# Out:
# (10841, 10)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
# Finding the rows
df_apps.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# dtype: int64

# %%
# All instances of null Ratings
df_apps[df_apps['Rating'].isnull()]
# Out:
#                                                App            Category  \
# 0                          Ak Parti Yardım Toplama              SOCIAL
# 1                       Ain Arabic Kids Alif Ba ta              FAMILY
# 2     Popsicle Launcher for Android P 9.0 launcher     PERSONALIZATION
# 3                        Command & Conquer: Rivals              FAMILY
# 4                                       CX Network            BUSINESS
# ...                                            ...                 ...
# 5840                                Em Fuga Brasil              FAMILY
# 5862                    Voice Tables - no internet           PARENTING
# 6141                                Young Speeches  LIBRARIES_AND_DEMO
# 7035                                SD card backup               TOOLS
# 7175                     Android TV Remote Service               TOOLS
#
#       Rating  Reviews  Size_MBs   Installs  Type   Price Content_Rating  \
# ...

# %%
df_apps.dropna(subset=['Rating'])
# Out:
#                                                    App Category  Rating  \
# 21                                 KBA-EZ Health Guide  MEDICAL    5.00
# 28                                            Ra Ga Ba     GAME    5.00
# 47                                             Mu.F.O.     GAME    5.00
# 82                                    Brick Breaker BR     GAME    5.00
# 99     Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00
# ...                                                ...      ...     ...
# 10836                                   Subway Surfers     GAME    4.50
# 10837                                   Subway Surfers     GAME    4.50
# 10838                                   Subway Surfers     GAME    4.50
# 10839                                   Subway Surfers     GAME    4.50
# 10840                                   Subway Surfers     GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type  Price Content_Rating   Genres
# ...

# %%
# Save result in variable
df_apps_clean = df_apps.dropna(subset=['Rating'])

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().value_counts()
# Out:
# False    8891
# True      476
# dtype: int64

# %%
df_apps_clean[df_apps_clean['App']=='Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
# Drop duplicates
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'])

# %%
# Check it worked
df_apps_clean[df_apps_clean['App']=='Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sort_values('Rating', ascending=False)[:10]
# Out:
#                                                    App      Category  Rating  \
# 21                                 KBA-EZ Health Guide       MEDICAL    5.00
# 1230                                      Sway Medical       MEDICAL    5.00
# 1227                                 AJ Men's Grooming     LIFESTYLE    5.00
# 1224                                    FK Dedinje BGD        SPORTS    5.00
# 1223                                   CB VIDEO VISION   PHOTOGRAPHY    5.00
# 1222                        Beacon Baptist Jupiter, FL     LIFESTYLE    5.00
# 1214                                    BV Mobile Apps  PRODUCTIVITY    5.00
# 2680                               Florida Wildflowers        FAMILY    5.00
# 1206                                      ADS-B Driver         TOOLS    5.00
# 2750  Superheroes, Marvel, DC, Comics, TV, Movies News        COMICS    5.00
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating        Genres
# ...

# %% [markdown]
# The main issue is that Rating for less popular apps is more likely to be higher. Best apps are going to be downloaded more frequently by people so we should factor in popularity when considering quality. This should be reflected in more reviews and therefore less likely to have 5 stars as all the abve examples show.

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values('Size_MBs', ascending=False)[:10]
# Out:
#                                                     App            Category  \
# 9942                     Talking Babsy Baby: Baby Games           LIFESTYLE
# 10687                            Hungry Shark Evolution                GAME
# 9943                              Miami crime simulator                GAME
# 9944                       Gangster Town: Vice District              FAMILY
# 3144                                         Vi Trainer  HEALTH_AND_FITNESS
# 9945                                    Ultimate Tennis              SPORTS
# 7926                                          Post Bank             FINANCE
# 7927                        The Walking Dead: Our World                GAME
# 7928                      Stickman Legends: Shadow Wars                GAME
# 4176   Car Crash III Beam DH Real Damage Simulator 2018                GAME
#
#        Rating  Reviews  Size_MBs     Installs  Type  Price Content_Rating  \
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
# Top ten most reviewed apps
df_apps_clean.sort_values('Reviews', ascending=False)[:10]
# Out:
#                                                      App       Category  \
# 10805                                           Facebook         SOCIAL
# 10785                                 WhatsApp Messenger  COMMUNICATION
# 10806                                          Instagram         SOCIAL
# 10784           Messenger – Text and Video Chat for Free  COMMUNICATION
# 10650                                     Clash of Clans           GAME
# 10744            Clean Master- Space Cleaner & Antivirus          TOOLS
# 10835                                     Subway Surfers           GAME
# 10828                                            YouTube  VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 10584                                       Clash Royale           GAME
#
#        Rating   Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805    4.10  78158306      5.30  1,000,000,000  Free     0           Teen
# ...

# %%
# Top fifty most reviewed apps
top_50 = df_apps_clean.sort_values('Reviews', ascending=False)[:50]
top_50['Type'].value_counts()
# Out:
# Free    50
# Name: Type, dtype: int64

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
# Content Rating counts
df_apps_clean.Content_Rating.value_counts()
# Out:
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
# Save rating counts in a variable
ratings = df_apps_clean.Content_Rating.value_counts()

# %%
import plotly.express as px
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
px.pie(labels=ratings.index, values=ratings.values)
# Out:
# <div>                            <div id="050e25b7-ec73-413e-8393-3fef5ceceeab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("050e25b7-ec73-413e-8393-3fef5ceceeab")) {                    Plotly.newPlot(                        "050e25b7-ec73-413e-8393-3fef5ceceeab",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"value=%{value}<extra></extra>","legendgroup":"","name":"","showlegend":false,"values":[6621,912,357,305,3,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd37
# ...

# %%
# Adding titles and better labelling
fig = px.pie(labels=ratings.index,
values=ratings.values,
title="Content Rating",
names=ratings.index,
)
fig.update_traces(textposition='outside', 
                  textinfo='percent+label')
# Out:
# <div>                            <div id="cacfd8a4-905d-4354-b941-4ff3b4a06a68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cacfd8a4-905d-4354-b941-4ff3b4a06a68")) {                    Plotly.newPlot(                        "cacfd8a4-905d-4354-b941-4ff3b4a06a68",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6621,912,357,305,3,1],"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks"
# ...

# %%
# Doughnut Version
fig = px.pie(labels=ratings.index,
             values=ratings.values,
             title="Content Rating",
             names=ratings.index,
             hole=0.4)

fig.update_traces(textposition='outside', 
                  textinfo='percent+label')
# Out:
# <div>                            <div id="bd96f217-bd4c-4eae-b182-6c7666b09a14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd96f217-bd4c-4eae-b182-6c7666b09a14")) {                    Plotly.newPlot(                        "bd96f217-bd4c-4eae-b182-6c7666b09a14",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6621,912,357,305,3,1],"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean['Installs'].sort_values(ascending=False)[:10]
# Out:
# 10731    500,000,000
# 10746    500,000,000
# 10711    500,000,000
# 10713    500,000,000
# 10717    500,000,000
# 10721    500,000,000
# 10722    500,000,000
# 10724    500,000,000
# 10734    500,000,000
# 10735    500,000,000
# Name: Installs, dtype: object

# %%
df_apps_clean['Installs'].sort_values()[:10]
# Out:
# 21          1
# 28          1
# 47          1
# 2136    1,000
# 2134    1,000
# 2133    1,000
# 2132    1,000
# 2131    1,000
# 2130    1,000
# 2129    1,000
# Name: Installs, dtype: object

# %%
type(df_apps_clean['Installs'].iloc[1])
# Out:
# str

# %%
# Changing the data type from string we first need to remove the commas
df_apps_clean['Installs'].str.replace(",","")
# Out:
# 21                1
# 28                1
# 47                1
# 82                5
# 99                5
#             ...
# 10824    1000000000
# 10828    1000000000
# 10829    1000000000
# 10831    1000000000
# 10835    1000000000
# Name: Installs, Length: 8199, dtype: object

# %%
df_apps_clean['Installs'] = df_apps_clean['Installs'].str.replace(",","")

# %%
# Then convert to numbers
df_apps_clean['Installs'] = pd.to_numeric(df_apps_clean['Installs'])

# %%
# Now we check this worked
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   int64
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 962.6+ KB

# %%
# We can now perform the groupby we wanted to do
# This shows how many apps have each installation count
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   int64
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 962.6+ KB

# %%
df_apps_clean[df_apps_clean['Price']!='0']
# Out:
#                                                     App   Category  Rating  \
# 28                                             Ra Ga Ba       GAME    5.00
# 47                                              Mu.F.O.       GAME    5.00
# 233              Chess of Blades (BL/Yaoi Game) (No VA)     FAMILY    4.80
# 248                                        The DG Buddy   BUSINESS    3.70
# 291                                 AC DC Power Monitor  LIFESTYLE    5.00
# ...                                                 ...        ...     ...
# 7957  League of Stickman 2018- Ninja Arena PVP(Dream...       GAME    4.40
# 7977                            Sleep as Android Unlock  LIFESTYLE    4.50
# 7988                                  Where's My Water?     FAMILY    4.70
# 8825                                      Hitman Sniper       GAME    4.60
# 9220                                          Minecraft     FAMILY    4.50
#
#       Reviews  Size_MBs  Installs  Type   Price Content_Rating  \
# ...

# %%
# First need to remove the $ from our strings
df_apps_clean['Price'] = df_apps_clean['Price'].str.replace("$","")
# Out:
# /var/folders/1f/1w554m957mz1kkr7yftsx8qr0000gn/T/ipykernel_59527/3699197788.py:2: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
# Then convert to numbers
df_apps_clean['Price'] = pd.to_numeric(df_apps_clean['Price'])

# %%
# Check it worked - price column should now show as a float
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   int64
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   float64
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 962.6+ KB

# %% [markdown]
# ### The most expensive apps sub $250

# %%
# Remove all apps that cost more than $250 from the df_apps_clean DataFrame.
df_apps_clean[df_apps_clean['Price']>250]
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2193             I am extremely Rich  LIFESTYLE    2.90       41      2.90
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 3856                   I am rich VIP  LIFESTYLE    3.80      411      2.60
# ...

# %%
# To remove these we:
df_apps_clean = df_apps_clean[df_apps_clean['Price'] <= 250]

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean['Revenue_Estimate'] = df_apps_clean['Price']*df_apps_clean['Installs']

# %%
df_apps_clean[['Price','Installs','Revenue_Estimate']].sample(10)
# Out:
#       Price  Installs  Revenue_Estimate
# 4038   0.00     10000              0.00
# 3809   0.00     10000              0.00
# 5333   3.99    100000        399,000.00
# 2596   0.99      1000            990.00
# 9485   0.00  10000000              0.00
# 7241   0.00   1000000              0.00
# 7067   0.00   1000000              0.00
# 2065   7.49      1000          7,490.00
# 9307   0.00  10000000              0.00
# 8084   0.00   5000000              0.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %% [markdown]
# If we are releasing an app we would like to target a category which is both popular but also one where the downloads are spread out among many different apps.
#
# That way, even if it’s more difficult to discover among all the other apps, your app has a better chance of getting installed, right?
#
# Let’s analyse this with bar charts and scatter plots and figure out which categories are dominating the market.

# %%
# Find the number of categories
df_apps_clean['Category'].nunique()
# Out:
# 33

# %%
# Find Number of apps per category
df_apps_clean['Category'].value_counts()
# Out:
# FAMILY                 1606
# GAME                    910
# TOOLS                   719
# PRODUCTIVITY            301
# PERSONALIZATION         298
# LIFESTYLE               297
# FINANCE                 296
# MEDICAL                 292
# PHOTOGRAPHY             263
# BUSINESS                262
# SPORTS                  260
# COMMUNICATION           257
# HEALTH_AND_FITNESS      243
# NEWS_AND_MAGAZINES      204
# SOCIAL                  203
# TRAVEL_AND_LOCAL        187
# SHOPPING                180
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           148
# DATING                  134
# EDUCATION               118
# MAPS_AND_NAVIGATION     118
# ENTERTAINMENT           102
# FOOD_AND_DRINK           94
# AUTO_AND_VEHICLES        73
# WEATHER                  72
# LIBRARIES_AND_DEMO       64
# HOUSE_AND_HOME           62
# ART_AND_DESIGN           61
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# ...

# %%
top10_category = df_apps_clean['Category'].value_counts()[:10]

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
bar = px.bar(x = top10_category.index,
             y = top10_category.values)
     
bar.show()
# Out:
# <div>                            <div id="db6de7bc-6104-42cd-a5db-9be1cfe9ea38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db6de7bc-6104-42cd-a5db-9be1cfe9ea38")) {                    Plotly.newPlot(                        "db6de7bc-6104-42cd-a5db-9be1cfe9ea38",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["FAMILY","GAME","TOOLS","PRODUCTIVITY","PERSONALIZATION","LIFESTYLE","FINANCE","MEDICAL","PHOTOGRAPHY","BUSINESS"],"xaxis":"x","y":[1606,910,719,301,298,297,296,292,263,262],"yaxis":"y","type":"bar"}],                        {"templ
# ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)
#
# But what if we look at it from a different perspective? What matters is not just the total number of apps in the category but how often apps are downloaded in that category.

# %%
df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
# Out:
#                         Installs
# Category
# ART_AND_DESIGN         114233100
# AUTO_AND_VEHICLES       53129800
# BEAUTY                  26916200
# BOOKS_AND_REFERENCE   1665791655
# BUSINESS               692018120
# COMICS                  44931100
# COMMUNICATION        11039241530
# DATING                 140912410
# EDUCATION              352852000
# ENTERTAINMENT         2113660000
# EVENTS                  15949410
# FAMILY                4437554490
# FINANCE                455249400
# FOOD_AND_DRINK         211677750
# GAME                 13858762717
# HEALTH_AND_FITNESS    1134006220
# HOUSE_AND_HOME          97082000
# LIBRARIES_AND_DEMO      52083000
# LIFESTYLE              503611120
# MAPS_AND_NAVIGATION    503267560
# MEDICAL                 39162676
# NEWS_AND_MAGAZINES    2369110650
# PARENTING               31116110
# PERSONALIZATION       1532352930
# PHOTOGRAPHY           4649143130
# PRODUCTIVITY          5788070180
# SHOPPING              1400331540
# ...

# %%
# Save and sort
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum}).sort_values('Installs')

# %%
# Check looks good!
category_installs
# Out:
#                         Installs
# Category
# EVENTS                  15949410
# BEAUTY                  26916200
# PARENTING               31116110
# MEDICAL                 39162676
# COMICS                  44931100
# LIBRARIES_AND_DEMO      52083000
# AUTO_AND_VEHICLES       53129800
# HOUSE_AND_HOME          97082000
# ART_AND_DESIGN         114233100
# DATING                 140912410
# FOOD_AND_DRINK         211677750
# EDUCATION              352852000
# WEATHER                361096500
# FINANCE                455249400
# MAPS_AND_NAVIGATION    503267560
# LIFESTYLE              503611120
# BUSINESS               692018120
# SPORTS                1096431465
# HEALTH_AND_FITNESS    1134006220
# SHOPPING              1400331540
# PERSONALIZATION       1532352930
# BOOKS_AND_REFERENCE   1665791655
# ENTERTAINMENT         2113660000
# NEWS_AND_MAGAZINES    2369110650
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3916897200
# FAMILY                4437554490
# ...

# %%
# Draw out our new version of the horizontal bar chart

px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')
 
h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
# Out:
# <div>                            <div id="9d2f40d9-f154-47ef-9a8d-fdf5d331154a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d2f40d9-f154-47ef-9a8d-fdf5d331154a")) {                    Plotly.newPlot(                        "9d2f40d9-f154-47ef-9a8d-fdf5d331154a",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[15949410,26916200,31116110,39162676,44931100,52083000,53129800,97082000,114233100,140912410,211677750,352852000,361096500,455249400,503267560,503611120,692018120,1096431465,1134006220,1400331540,1532352930,1665791655,2113660000,2369
# ...

# %% [markdown]
# Now we see that Games and Tools are actually the most popular categories. If we plot the popularity of a category next to the number of apps in that category we can get an idea of how concentrated a category is. Do few apps have most of the downloads or are the downloads spread out over many apps?

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
# Put Number of apps per category in a dataframe
df_apps_per_cat = df_apps_clean['Category'].value_counts().reset_index()
df_apps_per_cat.columns = ['Category','Count']

# %%
df_apps_per_cat.head()
# Out:
#           Category  Count
# 0           FAMILY   1606
# 1             GAME    910
# 2            TOOLS    719
# 3     PRODUCTIVITY    301
# 4  PERSONALIZATION    298

# %%
# Second df which is cateogries followed by number of installs
category_installs.head()
# Out:
#            Installs
# Category
# EVENTS     15949410
# BEAUTY     26916200
# PARENTING  31116110
# MEDICAL    39162676
# COMICS     44931100

# %%
# Use an inner merge as they share a column
pd.merge(df_apps_per_cat, category_installs, on='Category')
# Out:
#                Category  Count     Installs
# 0                FAMILY   1606   4437554490
# 1                  GAME    910  13858762717
# 2                 TOOLS    719   8099724500
# 3          PRODUCTIVITY    301   5788070180
# 4       PERSONALIZATION    298   1532352930
# 5             LIFESTYLE    297    503611120
# 6               FINANCE    296    455249400
# 7               MEDICAL    292     39162676
# 8           PHOTOGRAPHY    263   4649143130
# 9              BUSINESS    262    692018120
# 10               SPORTS    260   1096431465
# 11        COMMUNICATION    257  11039241530
# 12   HEALTH_AND_FITNESS    243   1134006220
# 13   NEWS_AND_MAGAZINES    204   2369110650
# 14               SOCIAL    203   5487841475
# 15     TRAVEL_AND_LOCAL    187   2894859300
# 16             SHOPPING    180   1400331540
# 17  BOOKS_AND_REFERENCE    169   1665791655
# 18        VIDEO_PLAYERS    148   3916897200
# 19               DATING    134    140912410
# ...

# %%
# Save our result
merged_df = pd.merge(df_apps_per_cat, category_installs, on='Category')

# %%
# Sort values
merged_df.sort_values('Installs', ascending=False)
# Out:
#                Category  Count     Installs
# 1                  GAME    910  13858762717
# 11        COMMUNICATION    257  11039241530
# 2                 TOOLS    719   8099724500
# 3          PRODUCTIVITY    301   5788070180
# 14               SOCIAL    203   5487841475
# 8           PHOTOGRAPHY    263   4649143130
# 0                FAMILY   1606   4437554490
# 18        VIDEO_PLAYERS    148   3916897200
# 15     TRAVEL_AND_LOCAL    187   2894859300
# 13   NEWS_AND_MAGAZINES    204   2369110650
# 22        ENTERTAINMENT    102   2113660000
# 17  BOOKS_AND_REFERENCE    169   1665791655
# 4       PERSONALIZATION    298   1532352930
# 16             SHOPPING    180   1400331540
# 12   HEALTH_AND_FITNESS    243   1134006220
# 10               SPORTS    260   1096431465
# 9              BUSINESS    262    692018120
# 5             LIFESTYLE    297    503611120
# 21  MAPS_AND_NAVIGATION    118    503267560
# 6               FINANCE    296    455249400
# ...

# %% [markdown]
# ## SCATTER

# %%
scatter = px.scatter(data_frame=merged_df,
                     x='Count',
                     y='Installs',
                     title='Category Concentration',
                     size='Count',  # Use a numerical column for size
                     hover_name='Category',  # Specify the column name for hover information
                     color='Installs')

scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))
# Out:
# <div>                            <div id="2b794cba-3083-407b-8f3e-e93b5301fd74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b794cba-3083-407b-8f3e-e93b5301fd74")) {                    Plotly.newPlot(                        "2b794cba-3083-407b-8f3e-e93b5301fd74",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Count=%{marker.size}<br>Installs=%{marker.color}<extra></extra>","hovertext":["FAMILY","GAME","TOOLS","PRODUCTIVITY","PERSONALIZATION","LIFESTYLE","FINANCE","MEDICAL","PHOTOGRAPHY","BUSINESS","SPORTS","COMMUNICATION","HEALTH_AND_FITNESS","NEWS_AND_MAGAZINES","SOCIAL","TRAVEL_AND_LOCAL","SHOPPING","BOOKS_AND_REFERENCE","VIDEO_PLAYERS","DATING","EDUCATION","MAPS_AND_NAVIGATION","ENTERTAINMENT","FOOD_AND_DRINK","AUTO_AND_
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
# Issue here is that multiple genres are being listed as a string
# Sepearted by the '&' sybmol
df_apps_clean['Genres'].value_counts()
# Out:
# Tools                                718
# Entertainment                        467
# Education                            429
# Productivity                         301
# Personalization                      298
#                                     ...
# Adventure;Brain Games                  1
# Travel & Local;Action & Adventure      1
# Art & Design;Pretend Play              1
# Music & Audio;Music & Video            1
# Lifestyle;Pretend Play                 1
# Name: Genres, Length: 114, dtype: int64

# %%
# To pull these out we can use the split and stack methods.
# Split the 'Genres' column and stack the resulting Series
df_apps_clean['Genres'].str.split('&', expand=True).stack()
# Out:
# 21     0           Medical
# 28     0            Arcade
# 47     0            Arcade
# 82     0            Arcade
# 99     0           Medical
#                  ...
# 10829  0    Video Players
#        1           Editors
# 10831  0             News
#        1         Magazines
# 10835  0            Arcade
# Length: 9742, dtype: object

# %%
stacked_genres = df_apps_clean['Genres'].str.split(';', expand=True).stack()

# %%
# Count the occurrences of each genre
stacked_genres.value_counts()
# Out:
# Tools                      719
# Education                  587
# Entertainment              498
# Action                     304
# Productivity               301
# Personalization            298
# Lifestyle                  298
# Finance                    296
# Medical                    292
# Sports                     270
# Photography                263
# Business                   262
# Communication              258
# Health & Fitness           245
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     185
# Shopping                   180
# Books & Reference          171
# Video Players & Editors    150
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# ...

# %%
genre_count = stacked_genres.value_counts()

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar_genres = px.bar(x = genre_count.index[:15], # index = category name
                    y = genre_count.values[:15], # count
                    title='Top Genres',
                    hover_name=genre_count.index[:15],
                    color=genre_count.values[:15],
                    color_continuous_scale='Agsunset')
 
bar_genres.update_layout(xaxis_title='Genre',
yaxis_title='Number of Apps',
coloraxis_showscale=False)
# Out:
# <div>                            <div id="35bf592f-0baa-44ec-af5c-618604947255" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35bf592f-0baa-44ec-af5c-618604947255")) {                    Plotly.newPlot(                        "35bf592f-0baa-44ec-af5c-618604947255",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","hovertext":["Tools","Education","Entertainment","Action","Productivity","Personalization","Lifestyle","Finance","Medical","Sports","Photography","Business","Communication","Health & Fitness","Casual"],"legendgroup":"","marker":{"color":[719,587,498,304,301,298,298,296,292,270,263,262,258,245,216],"coloraxis":"coloraxis","pattern":{"shape
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_apps_clean.groupby(['Category','Type'], as_index=False).count()
# Out:
#              Category  Type  App  Rating  Reviews  Size_MBs  Installs  Price  \
# 0      ART_AND_DESIGN  Free   58      58       58        58        58     58
# 1      ART_AND_DESIGN  Paid    3       3        3         3         3      3
# 2   AUTO_AND_VEHICLES  Free   72      72       72        72        72     72
# 3   AUTO_AND_VEHICLES  Paid    1       1        1         1         1      1
# 4              BEAUTY  Free   42      42       42        42        42     42
# ..                ...   ...  ...     ...      ...       ...       ...    ...
# 56   TRAVEL_AND_LOCAL  Paid    8       8        8         8         8      8
# 57      VIDEO_PLAYERS  Free  144     144      144       144       144    144
# 58      VIDEO_PLAYERS  Paid    4       4        4         4         4      4
# 59            WEATHER  Free   65      65       65        65        65     65
# 60            WEATHER  Paid    7       7        7         7         7      7
#
#     Content_Rating  Genres  Revenue_Estimate
# ...

# %%
df_free_vs_paid = df_apps_clean.groupby(['Category','Type'], as_index=False).count()

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
df_free_vs_paid.head()
# Out:
#             Category  Type  App  Rating  Reviews  Size_MBs  Installs  Price  \
# 0     ART_AND_DESIGN  Free   58      58       58        58        58     58
# 1     ART_AND_DESIGN  Paid    3       3        3         3         3      3
# 2  AUTO_AND_VEHICLES  Free   72      72       72        72        72     72
# 3  AUTO_AND_VEHICLES  Paid    1       1        1         1         1      1
# 4             BEAUTY  Free   42      42       42        42        42     42
#
#    Content_Rating  Genres  Revenue_Estimate
# 0              58      58                58
# 1               3       3                 3
# 2              72      72                72
# 3               1       1                 1
# 4              42      42                42

# %%
g_bar = px.bar(df_free_vs_paid,
                   x='Category',
                   y='App',
                   title='Free vs Paid Apps by Category',
                   color='Type',
                   barmode='group')
     
g_bar.update_layout(xaxis_title='Category',
                        yaxis_title='Number of Apps',
                        xaxis={'categoryorder':'total descending'},
                        yaxis=dict(type='log'))
# Out:
# <div>                            <div id="f6add5cf-ece5-46ee-b9c9-b264936bb90a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6add5cf-ece5-46ee-b9c9-b264936bb90a")) {                    Plotly.newPlot(                        "f6add5cf-ece5-46ee-b9c9-b264936bb90a",                        [{"alignmentgroup":"True","hovertemplate":"Type=Free<br>Category=%{x}<br>App=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALT
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_apps_clean,
                 y='Installs',
                 x='Type',
                 color='Type',
                 notched=True,
                 points='all',
                 title='How Many Downloads are Paid Apps Giving Up?')
     
box.update_layout(yaxis=dict(type='log'))
# Out:
# <div>                            <div id="0ac3a89d-d068-4211-a1ee-71d5ce94fbeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ac3a89d-d068-4211-a1ee-71d5ce94fbeb")) {                    Plotly.newPlot(                        "0ac3a89d-d068-4211-a1ee-71d5ce94fbeb",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Type=%{x}<br>Installs=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa"},"name":"Free","notched":true,"offsetgroup":"Free","orientation":"v","showlegend":true,"x":["Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free"
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']

box = px.box(df_paid_apps, 
                 x='Category', 
                 y='Revenue_Estimate',
                 title='How Much Can Paid Apps Earn?')
     
box.update_layout(xaxis_title='Category',
                      yaxis_title='Paid App Ballpark Revenue',
                      xaxis={'categoryorder':'min ascending'},
                      yaxis=dict(type='log'))
# Out:
# <div>                            <div id="f6dfb58b-1d33-4528-bb8e-c52a7f74aa3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6dfb58b-1d33-4528-bb8e-c52a7f74aa3b")) {                    Plotly.newPlot(                        "f6dfb58b-1d33-4528-bb8e-c52a7f74aa3b",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Revenue_Estimate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZAT
# ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
df_paid_apps.Price.median()
# Out:
# 2.99

# %%
box = px.box(df_paid_apps,
             x='Category',
             y="Price",
             title='Price per Category')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))
# Out:
# <div>                            <div id="47035639-52f1-4313-a946-ce2e44c14527" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47035639-52f1-4313-a946-ce2e44c14527")) {                    Plotly.newPlot(                        "47035639-52f1-4313-a946-ce2e44c14527",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZATION","PERSO
# ...
